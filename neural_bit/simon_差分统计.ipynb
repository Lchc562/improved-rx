# %%
import simon
import numpy as np

import numpy as np
from os import urandom
import random
from collections import Counter
import speck as sp
import numpy as np
from os import urandom
import random

from pickle import dump
print("test kernel")
# Out:
# test kernel

# %%
n = 10**6
nr = 8
data,y = simon.make_datas_demo(n,nr,k=3,diff=(0x0,0x102))
# data,y = simon.make_datas_demo(n,nr,k=15,diff=(0x0,0x3))
# print(data)
# 合并左右差分
data = (data[0].astype(np.uint32) << 16) ^ data[1]
# print(data)
count_dict = Counter(data)
print("可能差分种类数",len(count_dict))
# 使用sorted()函数按照字典的值进行排序，并返回一个列表
sort_list = sorted(count_dict.items(), key=lambda x: x[1], reverse=True)

diff_50 = sort_list[0:50]
# print(diff_50)
# 将list中的元组转换为list
diff_50 = list(map(list, diff_50))
# 只保留差分，删除统计的数量
diff_list = [sub_list[0] for sub_list in diff_50]
print("高概率差分：",diff_list,len(diff_list))
# 保留统计量，计算加权权重
diff_rat = [sub_list[1] for sub_list in diff_50]
print("差分对应数量",diff_rat,len(diff_rat))
diff_rat = [x / n for x in diff_rat]
print("差分统计概率：",diff_rat)
# Out:
# check_vector is no proplem
# 可能差分种类数 240827
# 高概率差分： [3502833664, 13180928, 1089019904, 15278080, 1086922752, 3236495360, 3504930816, 283713536, 1357455360, 1355358208, 281616384, 3536388224, 550053888, 3570466820, 1351106560, 3498590208, 1388904576, 3502784512, 1894328320, 1623271424, 1623795712, 3570991108, 3502768128, 3553165440, 1405681792, 820586496, 820062208, 549529600, 3503882244, 1893804032, 1355300864, 3503357956, 4035512336, 4034988048, 4037085200, 4037609488, 3769174032, 3766552592, 1086873600, 14229508, 3768649744, 1122574336, 3232260096, 3767076880, 2160615424, 3286835328, 3236454400, 16326660, 82911236, 3284738176] 50
# 差分对应数量 [1956, 1283, 1221, 1189, 1144, 1014, 955, 728, 726, 710, 695, 515, 515, 513, 511, 510, 509, 508, 496, 495, 494, 485, 482, 480, 479, 478, 476, 468, 467, 466, 450, 439, 386, 384, 382, 380, 375, 347, 338, 335, 332, 326, 324, 321, 320, 319, 318, 317, 317, 316] 50
# 差分统计概率： [0.001956, 0.001283, 0.001221, 0.001189, 0.001144, 0.001014, 0.000955, 0.000728, 0.000726, 0.00071, 0.000695, 0.000515, 0.000515, 0.000513, 0.000511, 0.00051, 0.000509, 0.000508, 0.000496, 0.000495, 0.000494, 0.000485, 0.000482, 0.00048, 0.000479, 0.000478, 0.000476, 0.000468, 0.000467, 0.000466, 0.00045, 0.000439, 0.000386, 0.000384, 0.000382, 0.00038, 0.000375, 0.000347, 0.000338, 0.000335, 0.000332, 0.000326, 0.000324, 0.000321, 0.00032, 0.000319, 0.000318, 0.000317, 0.000317, 0.000316]

# %%
# 创建一个包含十进制数字的列表
# decimal_numbers = [1359675395, 1343029251, 1342767107, 1393360899, 1376452611, 1342898179, 1359937539, 1359806467, 1343160323, 1359544323, 1376714755, 1376321539, 1393491971, 1393229827, 1376583683, 1393098755]
# decimal_numbers = [522539017, 2520076297, 388321289, 1064652809, 522670089, 2654425097, 929386505, 930435081, 1063604233, 2653376521, 523718665, 3061141513, 2654294025, 3061272585, 3060092937, 3060224009, 3194441737, 2519027721, 929517577, 2520207369, 389500937, 3194310665, 3195490313, 388452361, 389369865, 2653245449, 523587593, 3195359241, 2519158793, 930566153, 1063735305, 1064783881]
# 使用循环遍历列表并将每个数字转换为十六进制，并格式化为带有前导零的字符串
decimal_numbers = diff_list
hex_numbers = []
for decimal in decimal_numbers:
    hex_number = format(decimal, '#08x')
    hex_numbers.append(hex_number)

# 打印结果
# for i, decimal in enumerate(decimal_numbers):
#     print(f" {hex_numbers[i]}")
    
# 定义一个函数来计算汉明重量
def hamming_weight(hex_string):
    binary_string = bin(int(hex_string, 16))[2:]
    weight = binary_string.count('1')
    return weight

# 打印结果
for hex_number in hex_numbers:
    binary_number = bin(int(hex_number, 16))[2:]
    weight = hamming_weight(hex_number)
    print(f"{hex_number}, {binary_number}, Hamming Weight: {weight}")
# Out:
# 0xb6755009, 10110110011101010101000000001001, Hamming Weight: 14
# 0xbe755009, 10111110011101010101000000001001, Hamming Weight: 15
# 0x9e275009, 10011110001001110101000000001001, Hamming Weight: 13
# 0x96375009, 10010110001101110101000000001001, Hamming Weight: 13
# 0x96255009, 10010110001001010101000000001001, Hamming Weight: 11
# 0x96355009, 10010110001101010101000000001001, Hamming Weight: 12
# 0x17255009, 10111001001010101000000001001, Hamming Weight: 11
# 0x37655009, 110111011001010101000000001001, Hamming Weight: 13
# 0x3f655009, 111111011001010101000000001001, Hamming Weight: 14
# 0xbe775009, 10111110011101110101000000001001, Hamming Weight: 16
# 0x3f755009, 111111011101010101000000001001, Hamming Weight: 15
# 0xbe655009, 10111110011001010101000000001001, Hamming Weight: 14
# 0x3f675009, 111111011001110101000000001001, Hamming Weight: 15
# 0x9e355009, 10011110001101010101000000001001, Hamming Weight: 13
# 0x1f255009, 11111001001010101000000001001, Hamming Weight: 12
# 0x9e255009, 10011110001001010101000000001001, Hamming Weight: 12
# 0x37675009, 110111011001110101000000001001, Hamming Weight: 14
# 0x37755009, 110111011101010101000000001001, Hamming Weight: 14
# 0x9e375009, 10011110001101110101000000001001, Hamming Weight: 14
# 0xb6655009, 10110110011001010101000000001001, Hamming Weight: 13
# 0x96275009, 10010110001001110101000000001001, Hamming Weight: 12
# 0x1f375009, 11111001101110101000000001001, Hamming Weight: 14
# 0xbe675009, 10111110011001110101000000001001, Hamming Weight: 15
# 0x37775009, 110111011101110101000000001001, Hamming Weight: 15
# 0xb6775009, 10110110011101110101000000001001, Hamming Weight: 15
# 0x17375009, 10111001101110101000000001001, Hamming Weight: 13
# 0x17275009, 10111001001110101000000001001, Hamming Weight: 12
# 0x1f275009, 11111001001110101000000001001, Hamming Weight: 13
# 0xb6675009, 10110110011001110101000000001001, Hamming Weight: 14
# 0x1f355009, 11111001101010101000000001001, Hamming Weight: 13
# 0x17355009, 10111001101010101000000001001, Hamming Weight: 12
# 0x3f775009, 111111011101110101000000001001, Hamming Weight: 16
# 0x962b500b, 10010110001010110101000000001011, Hamming Weight: 13
# 0xb2775209, 10110010011101110101001000001001, Hamming Weight: 15
# 0x1f355209, 11111001101010101001000001001, Hamming Weight: 14
# 0x3f6d500b, 111111011011010101000000001011, Hamming Weight: 16
# 0xba675209, 10111010011001110101001000001001, Hamming Weight: 15
# 0xbc7d500b, 10111100011111010101000000001011, Hamming Weight: 16
# 0x1739500b, 10111001110010101000000001011, Hamming Weight: 13
# 0x3f7d500b, 111111011111010101000000001011, Hamming Weight: 17
# 0x3f7d500d, 111111011111010101000000001101, Hamming Weight: 17
# 0x1f3f500b, 11111001111110101000000001011, Hamming Weight: 16
# 0x1f3d500b, 11111001111010101000000001011, Hamming Weight: 15
# 0x1b3f500d, 11011001111110101000000001101, Hamming Weight: 15
# 0xbe75500d, 10111110011101010101000000001101, Hamming Weight: 16
# 0xba755209, 10111010011101010101001000001001, Hamming Weight: 15
# 0x356b500b, 110101011010110101000000001011, Hamming Weight: 14
# 0x9625500d, 10010110001001010101000000001101, Hamming Weight: 12
# 0x1f3d500d, 11111001111010101000000001101, Hamming Weight: 15
# 0x1735500d, 10111001101010101000000001101, Hamming Weight: 13
